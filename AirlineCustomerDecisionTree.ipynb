# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"D:\ML Assignments\Airline customer Satisfaction-Decision Tree\ML Project - Decision Tree Airline Customer Satisfaction U16955468980.txt")

# %%
data
# Out:
#       Unnamed: 0.1  Unnamed: 0      id  Gender      Customer Type  Age  \
# 0                0           0   70172    Male     Loyal Customer   13
# 1                1           1    5047    Male  disloyal Customer   25
# 2                2           2  110028  Female     Loyal Customer   26
# 3                3           3   24026  Female     Loyal Customer   25
# 4                4           4  119299    Male     Loyal Customer   61
# ...            ...         ...     ...     ...                ...  ...
# 9995          9995        9995  124365    Male     Loyal Customer   50
# 9996          9996        9996   22044    Male     Loyal Customer   38
# 9997          9997        9997   14057  Female     Loyal Customer   39
# 9998          9998        9998  113848    Male     Loyal Customer   52
# 9999          9999        9999    1865  Female     Loyal Customer   41
#
#        Type of Travel     Class  Flight Distance  Inflight wifi service  ...  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0             id           Age  \
# count   10000.00000  10000.00000   10000.000000  10000.000000
# mean     4999.50000   4999.50000   64950.978500     39.303700
# std      2886.89568   2886.89568   37420.905082     15.116478
# min         0.00000      0.00000       8.000000      7.000000
# 25%      2499.75000   2499.75000   32330.500000     27.000000
# 50%      4999.50000   4999.50000   64941.000000     40.000000
# 75%      7499.25000   7499.25000   97579.750000     51.000000
# max      9999.00000   9999.00000  129863.000000     85.000000
#
#        Flight Distance  Inflight wifi service  \
# count     10000.000000           10000.000000
# mean       1198.823800               2.731500
# std        1001.774138               1.328226
# min          31.000000               0.000000
# 25%         413.000000               2.000000
# 50%         852.500000               3.000000
# 75%        1747.000000               4.000000
# ...

# %%
data=data.drop(["Unnamed: 0.1","Unnamed: 0"],axis=1)

# %%
data
# Out:
#           id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0      70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1       5047    Male  disloyal Customer   25  Business travel  Business
# 2     110028  Female     Loyal Customer   26  Business travel  Business
# 3      24026  Female     Loyal Customer   25  Business travel  Business
# 4     119299    Male     Loyal Customer   61  Business travel  Business
# ...      ...     ...                ...  ...              ...       ...
# 9995  124365    Male     Loyal Customer   50  Business travel  Business
# 9996   22044    Male     Loyal Customer   38  Business travel  Business
# 9997   14057  Female     Loyal Customer   39  Business travel  Business
# 9998  113848    Male     Loyal Customer   52  Business travel  Business
# 9999    1865  Female     Loyal Customer   41  Business travel  Business
#
#       Flight Distance  Inflight wifi service  \
# 0                 460                      3
# ...

# %%
data.columns=[each.replace(" ","_") for each in data.columns]

# %%
data.columns
# Out:
# Index(['id', 'Gender', 'Customer_Type', 'Age', 'Type_of_Travel', 'Class',
#        'Flight_Distance', 'Inflight_wifi_service',
#        'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
#        'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
#        'Inflight_entertainment', 'On-board_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Inflight_service',
#        'Cleanliness', 'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
data["satisfaction"].unique()
# Out:
# array(['neutral or dissatisfied', 'satisfied'], dtype=object)

# %%
data["satisfaction"]=data["satisfaction"].replace(["neutral or dissatisfied","satisfied"],[0,1])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24104\1295690082.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["satisfaction"]=data["satisfaction"].replace(["neutral or dissatisfied","satisfied"],[0,1])

# %%
data.satisfaction
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: satisfaction, Length: 10000, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data["satisfaction"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='satisfaction'>

# %%
data[["satisfaction","Gender"]].groupby("Gender").mean()
# Out:
#         satisfaction
# Gender
# Female      0.424432
# Male        0.438062

# %%
data[["satisfaction","Age"]].groupby("Age").mean().sort_values(by="satisfaction",ascending=True)
# Out:
#      satisfaction
# Age
# 85       0.000000
# 76       0.000000
# 66       0.050000
# 7        0.071429
# 14       0.076923
# ..            ...
# 73       0.600000
# 45       0.608466
# 41       0.632743
# 46       0.643192
# 79       0.666667
#
# [74 rows x 1 columns]

# %%
data[["satisfaction","Food_and_drink"]].groupby("Food_and_drink").mean().sort_values(by="Food_and_drink",ascending=True)
# Out:
#                 satisfaction
# Food_and_drink
# 0                   0.625000
# 1                   0.198142
# 2                   0.362305
# 3                   0.404990
# 4                   0.515050
# 5                   0.566176

# %%
plt.boxplot(data["Flight_Distance"])
plt.show()

# %%
plt.boxplot(data["Checkin_service"])
plt.show()

# %%
data.isnull().sum()
# Out:
# id                                    0
# Gender                                0
# Customer_Type                         0
# Age                                   0
# Type_of_Travel                        0
# Class                                 0
# Flight_Distance                       0
# Inflight_wifi_service                 0
# Departure/Arrival_time_convenient     0
# Ease_of_Online_booking                0
# Gate_location                         0
# Food_and_drink                        0
# Online_boarding                       0
# Seat_comfort                          0
# Inflight_entertainment                0
# On-board_service                      0
# Leg_room_service                      0
# Baggage_handling                      0
# Checkin_service                       0
# Inflight_service                      0
# Cleanliness                           0
# Departure_Delay_in_Minutes            0
# Arrival_Delay_in_Minutes             26
# ...

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# id                                   0
# Gender                               0
# Customer_Type                        0
# Age                                  0
# Type_of_Travel                       0
# Class                                0
# Flight_Distance                      0
# Inflight_wifi_service                0
# Departure/Arrival_time_convenient    0
# Ease_of_Online_booking               0
# Gate_location                        0
# Food_and_drink                       0
# Online_boarding                      0
# Seat_comfort                         0
# Inflight_entertainment               0
# On-board_service                     0
# Leg_room_service                     0
# Baggage_handling                     0
# Checkin_service                      0
# Inflight_service                     0
# Cleanliness                          0
# Departure_Delay_in_Minutes           0
# Arrival_Delay_in_Minutes             0
# satisfaction                         0
# dtype: int64

# %%
data["Flight_Distance"].unique()
# Out:
# array([ 460,  235, 1142, ..., 3033, 1319, 1443], dtype=int64)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
data[["Gender","Customer_Type","Type_of_Travel","Class"]]=data[["Gender","Customer_Type","Type_of_Travel","Class"]].apply(enc.fit_transform)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24104\1869947289.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["Gender","Customer_Type","Type_of_Travel","Class"]]=data[["Gender","Customer_Type","Type_of_Travel","Class"]].apply(enc.fit_transform)

# %%
data=data.drop("id",axis=1)

# %%
data
# Out:
#       Gender  Customer_Type  Age  Type_of_Travel  Class  Flight_Distance  \
# 0          1              0   13               1      2              460
# 1          1              1   25               0      0              235
# 2          0              0   26               0      0             1142
# 3          0              0   25               0      0              562
# 4          1              0   61               0      0              214
# ...      ...            ...  ...             ...    ...              ...
# 9995       1              0   50               0      0             3599
# 9996       1              0   38               0      0             3873
# 9997       0              0   39               0      0              319
# 9998       1              0   52               0      0             1363
# 9999       0              0   41               0      0             3938
#
#       Inflight_wifi_service  Departure/Arrival_time_convenient  \
# ...

# %%
x=data.drop("satisfaction",axis=1)

# %%
y=data.satisfaction

# %%
from sklearn.preprocessing import StandardScaler

# %%
std=StandardScaler()

# %%
std.fit_transform(x)
# Out:
# array([[ 1.022101  , -0.46815207, -1.7390128 , ...,  1.31151575,
#          0.2672691 ,  0.07106403],
#        [ 1.022101  ,  2.13605805, -0.9454767 , ..., -1.71598135,
#         -0.3602227 , -0.23814858],
#        [-0.9783769 , -0.46815207, -0.87934869, ...,  1.31151575,
#         -0.38636819, -0.39275488],
#        ...,
#        [-0.9783769 , -0.46815207, -0.01968459, ..., -0.95910708,
#         -0.38636819, -0.39275488],
#        [ 1.022101  , -0.46815207,  0.83997952, ...,  1.31151575,
#         -0.3602227 , -0.10930999],
#        [-0.9783769 , -0.46815207,  0.11257143, ...,  0.55464148,
#         -0.38636819, -0.39275488]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=10)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier(max_depth=5)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
model.score(x_train,y_train)
# Out:
# 0.9052512846221331

# %%
model.score(x_test,y_test)
# Out:
# 0.9047619047619048

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,f1_score,classification_report

# %%
accuracy_score(y_test,model.predict(x_test))
# Out:
# 0.9047619047619048

# %%
precision_score(y_test,model.predict(x_test))
# Out:
# 0.9057071960297767

# %%
recall_score(y_test,model.predict(x_test))
# Out:
# 0.8649289099526066

# %%
f1_score(y_test,model.predict(x_test))
# Out:
# 0.8848484848484849

# %%
confusion_matrix(y_test,model.predict(x_test))
# Out:
# array([[1075,   76],
#        [ 114,  730]], dtype=int64)

# %%
print(classification_report(y_test,model.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.92      1151
#            1       0.91      0.86      0.88       844
#
#     accuracy                           0.90      1995
#    macro avg       0.90      0.90      0.90      1995
# weighted avg       0.90      0.90      0.90      1995
